# %% [markdown]
# <a href="https://colab.research.google.com/github/avirupk/Amazon-Clone-Website/blob/main/Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_frame=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/ML/1_linear_reg/homeprices.csv")

# %%
data_frame
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(data_frame.area,data_frame.price,color="g")
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("Area vs Price Plot")
plt.show()

# %%
new_data=data_frame.drop("price",axis=1)

# %%
new_data
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price=data_frame["price"]
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
from sklearn import linear_model

# %%
# create linear regression
reg=linear_model.LinearRegression()
reg.fit(new_data,price)
# Out:
# LinearRegression()

# %% [markdown]
# Find the price of 3300 sqft area

# %%
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %% [markdown]
# SLOPE

# %%
reg.coef_
# Out:
# array([135.78767123])

# %% [markdown]
# INTERCEPT

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %% [markdown]
# PRICE = ( SLOPE * AREA ) + INTERCEPT

# %%
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %% [markdown]
# Find the price of the area of 5000 sqft

# %%
reg.predict([[5000]])
# Out:
# array([859554.79452055])

# %% [markdown]
# find the price of a list of areas

# %%
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/ML/1_linear_reg/areas.csv")

# %%
df
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
prices_list=reg.predict(df)
prices_list
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
df["price"]=prices_list

# %%
df
# Out:
#     area         price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
df.to_csv("price_prediction")

# %% [markdown]
# # Excercise

# %% [markdown]
# Predict canada's per capita income in year 2020. There is an exercise folder here on github at same level as this notebook, download that and you will find canada_per_capita_income.csv file. Using this build a regression model and predict the per capita income fo canadian citizens in year 2020

# %%
df1=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/ML/1_linear_reg/Exercise/canada_per_capita_income.csv")

# %%
df1.head(10)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583
# 5  1975              5998.144346
# 6  1976              7062.131392
# 7  1977              7100.126170
# 8  1978              7247.967035
# 9  1979              7602.912681

# %%
sns.scatterplot(y="per capita income (US$)",x="year",data=df1,
                color="r")
plt.title("year vs per capita income (US$) plot")
plt.show()

# %%
ndf1=df1.drop("per capita income (US$)",axis=1)
ndf1.head(10)
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974
# 5  1975
# 6  1976
# 7  1977
# 8  1978
# 9  1979

# %%
price_df1=df1["per capita income (US$)"]
price_df1
# Out:
# 0      3399.299037
# 1      3768.297935
# 2      4251.175484
# 3      4804.463248
# 4      5576.514583
# 5      5998.144346
# 6      7062.131392
# 7      7100.126170
# 8      7247.967035
# 9      7602.912681
# 10     8355.968120
# 11     9434.390652
# 12     9619.438377
# 13    10416.536590
# 14    10790.328720
# 15    11018.955850
# 16    11482.891530
# 17    12974.806620
# 18    15080.283450
# 19    16426.725480
# 20    16838.673200
# 21    17266.097690
# 22    16412.083090
# 23    15875.586730
# 24    15755.820270
# 25    16369.317250
# 26    16699.826680
# 27    17310.757750
# 28    16622.671870
# 29    17581.024140
# 30    18987.382410
# 31    18601.397240
# 32    19232.175560
# 33    22739.426280
# 34    25719.147150
# 35    29198.055690
# 36    32738.262900
# 37    36144.481220
# 38    37446.486090
# 39    32755.176820
# 40    38420.522890
# 41    42334.711210
# 42    42665.255970
# 43    42676.468370
# 44    41039.893600
# 45    35175.188980
# 46    34229.193630
# ...

# %%
reg2=linear_model.LinearRegression()
reg2.fit(ndf1,price_df1)
# Out:
# LinearRegression()

# %% [markdown]
# **find the per capita income (US$) in 2020**

# %%
reg2.predict([[2020]])
# Out:
# array([41288.69409442])
